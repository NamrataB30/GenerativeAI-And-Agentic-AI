# %% [markdown]
# Step 1: Text → Text using Gemini
#
#
# a. Google AI Studio
# b. Click Get API Key
# c. Click Create API Key

# %%
# !pip install -q google-genai

# %%
from google import genai

# %%
from google import genai

client = genai.Client(
    api_key="abc"
)

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="Explain Data Science in simple words."
)

print(response.text)
# Out:
# Imagine you have a **huge pile of stuff** – not just any stuff, but information: numbers, words, pictures, sounds, everything. This pile is called **data**.
#
# Now, imagine you're a **detective** (that's the Data Scientist!). Your job is to:
#
# 1.  **Sift through the pile:** Collect all the relevant clues (data).
# 2.  **Clean up the mess:** Organize the clues, throw out the irrelevant bits, and make sure everything is in order.
# 3.  **Look for patterns:** Find connections, trends, and things that repeat. (Like, "Every time it rains, people buy more umbrellas.")
# 4.  **Figure out what happened/what's happening:** Understand the story the clues are telling. ("Why are our sales going down?")
# 5.  **Predict what might happen next:** Based on the patterns, try to guess the future. ("If this trend continues, we'll sell even fewer umbrellas next month.")
# 6.  **Tell the story simply:** Explain your findings to others so they can understand and use the information.
#
# ...

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="What is 25 + 25?"
)

print(response.text)
# Out:
# 25 + 25 = 50

# %% [markdown]
# Step 2: Image → Text

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-ac12b064-3d7b-463b-b39c-47a39076d29d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ac12b064-3d7b-463b-b39c-47a39076d29d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from PIL import Image

img = Image.open("elg21-bird-8788491_1920.jpg")

img
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
from google import genai
from PIL import Image

client = genai.Client(api_key="abc")

img = Image.open("elg21-bird-8788491_1920.jpg")

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=[
        "Describe this image in detail",
        img
    ]
)

print(response.text)
# Out:
# This vibrant and serene image captures a magnificent blue bird perched on a branch adorned with delicate white blossoms against a soft, cloudy blue sky.
#
# **Central Subjects:**
#
# *   **The Bird:** Dominating the right side of the frame is a small, plump bird with striking, iridescent blue plumage. Its feathers appear soft and fluffy, especially on its breast and back, showcasing varying shades of azure, sapphire, and a lighter sky blue. The wings and tail feathers are a slightly darker, more defined blue. The bird has a small, dark, pointed beak and a distinct, dark eye that conveys alertness. It is perched with its dark, slender legs and visible claws gripping the gnarled branch, facing slightly to the left, as if gazing into the distance or contemplating the blossoms.
#
# ...

# %% [markdown]
# Step 3: Audio → Text (Speech Recognition)
#
# Whisper is one of the most widely used speech-to-text models.

# %%
# !pip install -q openai-whisper
# !apt-get -qq install ffmpeg
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.2/803.2 kB 3.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.5/201.5 MB 7.3 MB/s eta 0:00:00
# ...

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-0fc7014a-31d1-4fd2-bba3-6486144a3fd2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0fc7014a-31d1-4fd2-bba3-6486144a3fd2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import whisper

model = whisper.load_model("base")
# Out:
# 100%|████████████████████████████████████████| 139M/139M [00:01<00:00, 135MiB/s]

# %%
result = model.transcribe("Recording.m4a")

print(result["text"])
# Out:
# /usr/local/lib/python3.12/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  Hello, I'm Numerata and I'm learning multi-model AI.

# %%
result = model.transcribe(
    "Recording.m4a",
    task="transcribe"
)
# Out:
# /usr/local/lib/python3.12/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")

# %% [markdown]
# Step 4: Text → Audio (Text-to-Speech)
#
# gTTS
#
# Why?
#
# Easy to use
# Free
# Works well for demonstrations

# %%
# !pip install gtts

# %%
from gtts import gTTS

text = """
Welcome to the world of Artificial Intelligence.
This audio was generated using a Text-to-Speech model.
"""

tts = gTTS(text=text, lang='en')

tts.save("output.mp3")

# %%
from IPython.display import Audio

Audio("output.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Step 5: Text → Image

# %%
# !pip install -q diffusers transformers accelerate sentencepiece
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.6/116.6 kB 1.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gtts 2.5.4 requires click<8.2,>=7.1, but you have click 8.4.1 which is incompatible.

# %%
# !pip install -q torch

# %% [markdown]
# Step 1
#
# Create a Hugging Face account:
#
# Hugging Face
#
# Step 2
#
# Generate an access token:
#
# Access Tokens
#
# Create a Read token.
#
# Step 3
#
# Accept the FLUX model license:
#
# FLUX.1 Schnell Model Page
#
# Click Agree and Access Repository.

# %%
from huggingface_hub import login

login("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")

# %%
from diffusers import StableDiffusionPipeline
import torch

pipe = StableDiffusionPipeline.from_pretrained(
    "runwayml/stable-diffusion-v1-5",
    torch_dtype=torch.float16
)

pipe = pipe.to("cuda")
# Out:
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:112: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# ...
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# ...

# %% [markdown]
# Runtime
#     ↓
# Change runtime type
#     ↓
# Hardware accelerator
#     ↓
# GPU
#     ↓
# Save

# %%
prompt = "A futuristic city with flying cars at sunset"

image = pipe(prompt).images[0]

image
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %% [markdown]
# Step 6: Video → Text

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-a50dba00-2ff2-4ca7-b6c8-5b5a97b4831c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a50dba00-2ff2-4ca7-b6c8-5b5a97b4831c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import time

video_file = client.files.upload(
    file="VID_20230410_071051.mp4"
)

while video_file.state.name != "ACTIVE":
    print("Waiting for video processing...")
    time.sleep(5)

    video_file = client.files.get(
        name=video_file.name
    )

print("Video is ready!")
# Out:
# Waiting for video processing...
# Waiting for video processing...
# Waiting for video processing...
# Video is ready!

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=[
        video_file,
        "Describe this video in detail."
    ]
)

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_616/3619737823.py in <cell line: 0>()
# ----> 1 response = client.models.generate_content(
#       2     model="gemini-2.5-flash",
#       3     contents=[
#       4         video_file,
#       5         "Describe this video in detail."
#
# NameError: name 'client' is not defined

# %%
# !pip install replicate
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.6/48.6 kB 5.1 MB/s eta 0:00:00
# ...

# %%
import os

os.environ["REPLICATE_API_TOKEN"] = "abc"

# %%
import replicate

output = replicate.run(
    "minimax/video-01",
    input={
        "prompt": "A futuristic city with flying cars at sunset"
    }
)

print(output)
# Out:
# https://replicate.delivery/xezq/MyNSfK2droRkSKUBIXZrcBKeBzkuRueK2KEuifCrumF86SnaB/tmpe9ez0kgd.mp4
